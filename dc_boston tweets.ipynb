# %%
import numpy as np
import re
import pandas as pd
import seaborn as sns
from wordcloud import WordCloud, STOPWORDS
from matplotlib import pyplot as plt

# %%
data_set = pd.read_csv('COVID-tweets.csv')

# %%
data_set_DC = data_set[data_set['Tweet Location'] == 'Washington, DC'].reset_index()

# %%
data_set_DC.drop('index', axis = 1, inplace = True)

# %%
data_set_DC
# Out:
#                   Tweet Id                                          Tweet URL  \
# 0    "1233415561394171904"  https://twitter.com/peoplefor/status/123341556...
# 1    "1233414997092585473"  https://twitter.com/matthewstoller/status/1233...
# 2    "1233414115172941828"  https://twitter.com/CathyHackl/status/12334141...
# 3    "1233414061020319745"  https://twitter.com/AppropsDems/status/1233414...
# 4    "1233414050903740416"  https://twitter.com/rschles/status/12334140509...
# ..                     ...                                                ...
# 279  "1220858355100667905"  https://twitter.com/ManiificentT/status/122085...
# 280  "1216768678060052481"  https://twitter.com/GavinMacSkin/status/121676...
# 281  "1216731249097601024"  https://twitter.com/RebeccaKatz5/status/121673...
# 282  "1216730560946671617"  https://twitter.com/jimfryVOA/status/121673056...
# 283  "1216729981323300865"  https://twitter.com/karmanomad/status/12167299...
#
#     Tweet Posted Time (UTC)  \
# ...

# %%
data_set_boston = data_set[data_set['Tweet Location'] == 'Boston'].reset_index()

# %%
data_set_boston.drop('index', axis = 1, inplace = True)

# %%
data_set_boston
# Out:
#                  Tweet Id                                          Tweet URL  \
# 0   "1233413414040592384"  https://twitter.com/wbz/status/123341341404059...
# 1   "1233398319235371008"  https://twitter.com/GlobeOpinion/status/123339...
# 2   "1232294793486782464"  https://twitter.com/GlobeOpinion/status/123229...
# 3   "1230939061575200768"  https://twitter.com/CCWoolf/status/12309390615...
# 4   "1223387761132101633"  https://twitter.com/Budz442Bud/status/12233877...
# 5   "1223386433202925569"  https://twitter.com/jsendslove/status/12233864...
# 6   "1223385369200250881"  https://twitter.com/Budz442Bud/status/12233853...
# 7   "1223379581412966406"  https://twitter.com/BrandMoxi/status/122337958...
# 8   "1223376305577701382"  https://twitter.com/newscam12/status/122337630...
# 9   "1223366313415991296"  https://twitter.com/Budz442Bud/status/12233663...
# 10  "1223363048368492547"  https://twitter.com/PoliticalGeek/status/12233...
# ...

# %%
x = pd.merge(data_set_DC, data_set_boston, how = 'outer')

# %%
x.to_csv('dc_boston_tweets.csv')
