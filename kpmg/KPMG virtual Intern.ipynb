# %%
import pandas as pd

# %%
data_set = pd.read_excel(open('kpmg_dataset.xlsx', 'rb'),
              sheet_name='Transactions', skiprows = 1)

# %%
data_set.head()
# Out:
#    transaction_id  product_id  customer_id transaction_date  online_order  \
# 1               2           3         3120       2017-05-21           1.0
# 2               3          37          402       2017-10-16           0.0
# 3               4          88         3135       2017-08-31           0.0
# 4               5          78          787       2017-10-01           1.0
# 5               6          25         2339       2017-03-08           1.0
#
#   order_status           brand product_line product_class product_size  \
# 1     Approved   Trek Bicycles     Standard        medium        large
# 2     Approved      OHM Cycles     Standard           low       medium
# 3     Approved  Norco Bicycles     Standard        medium       medium
# 4     Approved  Giant Bicycles     Standard        medium        large
# 5     Approved  Giant Bicycles         Road        medium       medium
#
#    list_price  standard_cost  product_first_sold_date
# ...

# %%
data_set['year'] = pd.DatetimeIndex(data_set['transaction_date']).year
data_set['year'].value_counts()
# Out:
# C:\Users\user\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# 2017    19999
# Name: year, dtype: int64

# %%
data_set.describe()
# Out:
#        transaction_id    product_id   customer_id  online_order    list_price  \
# count    19999.000000  19999.000000  19999.000000  19639.000000  19999.000000
# mean     10001.000000     45.366818   1738.185459      0.500484   1107.881269
# std       5773.358353     30.752830   1011.940066      0.500012    582.793738
# min          2.000000      0.000000      1.000000      0.000000     12.010000
# 25%       5001.500000     18.000000    857.500000      0.000000    575.270000
# 50%      10001.000000     44.000000   1736.000000      1.000000   1163.890000
# 75%      15000.500000     72.000000   2613.000000      1.000000   1635.300000
# max      20000.000000    100.000000   5034.000000      1.000000   2091.470000
#
#        standard_cost  product_first_sold_date
# count   19802.000000             19802.000000
# mean      556.072324             38199.622765
# std       405.950208              2875.192266
# min         7.210000             33259.000000
# ...

# %%
data_set.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19999 entries, 1 to 19999
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   transaction_id           19999 non-null  int64
#  1   product_id               19999 non-null  int64
#  2   customer_id              19999 non-null  int64
#  3   transaction_date         19999 non-null  datetime64[ns]
#  4   online_order             19639 non-null  float64
#  5   order_status             19999 non-null  object
#  6   brand                    19802 non-null  object
#  7   product_line             19802 non-null  object
#  8   product_class            19802 non-null  object
#  9   product_size             19802 non-null  object
#  10  list_price               19999 non-null  float64
#  11  standard_cost            19802 non-null  float64
#  12  product_first_sold_date  19802 non-null  float64
# ...

# %%
data_set.isnull().sum()
# Out:
# transaction_id               0
# product_id                   0
# customer_id                  0
# transaction_date             0
# online_order               360
# order_status                 0
# brand                      197
# product_line               197
# product_class              197
# product_size               197
# list_price                   0
# standard_cost              197
# product_first_sold_date    197
# dtype: int64

# %%
import seaborn as sns
import numpy as np
import matplotlib as plt

# %%
data_set.columns
# Out:
# Index(['transaction_id', 'product_id', 'customer_id', 'transaction_date',
#        'online_order', 'order_status', 'brand', 'product_line',
#        'product_class', 'product_size', 'list_price', 'standard_cost',
#        'product_first_sold_date'],
#       dtype='object')

# %%
Q1 = data_set['transaction_id'].quantile(0.25)
Q3 = data_set['transaction_id'].quantile(0.75)
IQR = Q3 - Q1
print(IQR)
# Out:
# 9999.0

# %%
len(data_set['transaction_id'])
# Out:
# 19999

# %%
data_set.loc[1, 'transaction_id']
# Out:
# 2

# %%
col = ['transaction_id', 'product_id', 'customer_id', 
        'list_price', 'standard_cost',
       'product_first_sold_date']

# %%
x = (data_set['transaction_id'] < (Q1 - 1.5 * IQR)) | (data_set['transaction_id'] > (Q3 + 1.5 * IQR))

# %%
for j in col:
    Q1 = data_set[j].quantile(0.25)
    Q3 = data_set[j].quantile(0.75)
    IQR = Q3 - Q1
    #print(IQR)

    for i in range(1, 19999):
        if (data_set.loc[1, j] < (Q1 - 1.5 * IQR) == True):
            print("Outlier at", i, "in ", j)
        if (data_set.loc[1, j] > (Q3 + 1.5 * IQR) == True):
            print("Outlier at", i, "in ", j)

# %%
data_set2 = pd.read_excel(open('kpmg_dataset.xlsx', 'rb'),
              sheet_name='NewCustomerList', skiprows = 1)

# %%
pd.set_option("display.max_columns", 100)

# %%
data_set2.head()
# Out:
#   first_name  last_name  gender  past_3_years_bike_related_purchases  \
# 0    Chickie    Brister    Male                                   86
# 1      Morly     Genery    Male                                   69
# 2    Ardelis  Forrester  Female                                   10
# 3     Lucine      Stutt  Female                                   64
# 4    Melinda     Hadlee  Female                                   34
#
#          DOB                   job_title job_industry_category  \
# 0 1957-07-12             General Manager         Manufacturing
# 1 1970-03-22         Structural Engineer              Property
# 2 1974-08-28      Senior Cost Accountant    Financial Services
# 3 1979-01-28  Account Representative III         Manufacturing
# 4 1965-09-21           Financial Analyst    Financial Services
#
#       wealth_segment deceased_indicator owns_car  tenure              address  \
# 0      Mass Customer                  N      Yes      14     45 Shopko Center
# ...

# %%
data_set2.isnull().sum()
# Out:
# first_name                               0
# last_name                               29
# gender                                   0
# past_3_years_bike_related_purchases      0
# DOB                                     17
# job_title                              106
# job_industry_category                  165
# wealth_segment                           0
# deceased_indicator                       0
# owns_car                                 0
# tenure                                   0
# address                                  0
# postcode                                 0
# state                                    0
# country                                  0
# property_valuation                       0
# Unnamed: 16                              0
# Unnamed: 17                              0
# Unnamed: 18                              0
# Unnamed: 19                              0
# Unnamed: 20                              0
# Rank                                     0
# ...

# %%
data_set2['year'] = pd.DatetimeIndex(data_set2['DOB']).year
data_set2['year'].value_counts()
# Out:
# 1974.0    29
# 1978.0    27
# 1976.0    27
# 1973.0    27
# 1961.0    26
#           ..
# 1948.0     7
# 1989.0     6
# 1984.0     5
# 1949.0     4
# 2002.0     3
# Name: year, Length: 65, dtype: int64

# %%
data_set2['year'].sort_values()
# Out:
# 585    1938.0
# 406    1938.0
# 885    1938.0
# 689    1938.0
# 977    1938.0
#         ...
# 775       NaN
# 835       NaN
# 883       NaN
# 904       NaN
# 984       NaN
# Name: year, Length: 1000, dtype: float64

# %%
data_set2.columns
# Out:
# Index(['first_name', 'last_name', 'gender',
#        'past_3_years_bike_related_purchases', 'DOB', 'job_title',
#        'job_industry_category', 'wealth_segment', 'deceased_indicator',
#        'owns_car', 'tenure', 'address', 'postcode', 'state', 'country',
#        'property_valuation', 'Unnamed: 16', 'Unnamed: 17', 'Unnamed: 18',
#        'Unnamed: 19', 'Unnamed: 20', 'Rank', 'Value'],
#       dtype='object')

# %%
data_set2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 23 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   first_name                           1000 non-null   object
#  1   last_name                            971 non-null    object
#  2   gender                               1000 non-null   object
#  3   past_3_years_bike_related_purchases  1000 non-null   int64
#  4   DOB                                  983 non-null    datetime64[ns]
#  5   job_title                            894 non-null    object
#  6   job_industry_category                835 non-null    object
#  7   wealth_segment                       1000 non-null   object
#  8   deceased_indicator                   1000 non-null   object
#  9   owns_car                             1000 non-null   object
#  10  tenure                               1000 non-null   int64
# ...

# %%
col2 = ['past_3_years_bike_related_purchases', 'tenure',  'postcode', 
       'property_valuation', 'Unnamed: 16', 'Unnamed: 17', 'Unnamed: 18',
       'Unnamed: 19', 'Unnamed: 20', 'Rank', 'Value']

# %%
len(data_set2)
# Out:
# 1000

# %%
for j in col2:
    Q1 = data_set2[j].quantile(0.25)
    Q3 = data_set2[j].quantile(0.75)
    IQR = Q3 - Q1
    #print(IQR)

    for i in range(1, 1000):
        if (data_set2.loc[1, j] < (Q1 - 1.5 * IQR) == True):
            print("Outlier at", i, "in ", j)
        if (data_set2.loc[1, j] > (Q3 + 1.5 * IQR) == True):
            print("Outlier at", i, "in ", j)

# %%
data_set3 = pd.read_excel(open('kpmg_dataset.xlsx', 'rb'),
              sheet_name='CustomerDemographic', skiprows = 1)

# %%
data_set3.head()
# Out:
#    customer_id      first_name  last_name  gender  \
# 0            1         Laraine  Medendorp       F
# 1            2             Eli    Bockman    Male
# 2            3           Arlin     Dearle    Male
# 3            4          Talbot        NaN    Male
# 4            5  Sheila-kathryn     Calton  Female
#
#    past_3_years_bike_related_purchases        DOB               job_title  \
# 0                                   93 1953-10-12     Executive Secretary
# 1                                   81 1980-12-16  Administrative Officer
# 2                                   61 1954-01-20      Recruiting Manager
# 3                                   33 1961-10-03                     NaN
# 4                                   56 1977-05-13           Senior Editor
#
#   job_industry_category     wealth_segment deceased_indicator  \
# 0                Health      Mass Customer                  N
# 1    Financial Services      Mass Customer                  N
# ...

# %%
data_set3.isnull().sum()
# Out:
# customer_id                              0
# first_name                               0
# last_name                              125
# gender                                   0
# past_3_years_bike_related_purchases      0
# DOB                                     87
# job_title                              506
# job_industry_category                  656
# wealth_segment                           0
# deceased_indicator                       0
# default                                302
# owns_car                                 0
# tenure                                  87
# dtype: int64

# %%
data_set3['year'] = pd.DatetimeIndex(data_set3['DOB']).year
data_set3['year'].value_counts()
# Out:
# 1978.0    217
# 1977.0    204
# 1976.0    152
# 1974.0    152
# 1980.0    123
# 1973.0    122
# 1979.0    118
# 1986.0    114
# 1975.0    114
# 1959.0     94
# 1985.0     91
# 1995.0     90
# 1971.0     88
# 1964.0     85
# 1998.0     80
# 1981.0     79
# 1994.0     79
# 1969.0     78
# 1962.0     76
# 1997.0     74
# 1989.0     74
# 1992.0     74
# 1967.0     73
# 1987.0     72
# 1988.0     72
# 1957.0     71
# 1965.0     69
# 1968.0     69
# 1996.0     67
# 1966.0     65
# 1956.0     63
# 1954.0     61
# 1961.0     60
# 1999.0     60
# 1993.0     60
# 1963.0     59
# 1960.0     58
# 1955.0     58
# 1970.0     57
# 1958.0     55
# 1972.0     54
# 1990.0     53
# 1991.0     48
# 1984.0     43
# 2000.0     42
# 1982.0     41
# 1983.0     40
# 2001.0     34
# 1953.0     19
# 2002.0      6
# 1943.0      1
# 1843.0      1
# 1935.0      1
# 1944.0      1
# 1931.0      1
# 1940.0      1
# Name: year, dtype: int64

# %%
data_set3['year'].sort_values()
# Out:
# 33      1843.0
# 719     1931.0
# 1091    1935.0
# 3409    1940.0
# 2412    1943.0
# 657     1944.0
# 0       1953.0
# 424     1953.0
# 2745    1953.0
# 2812    1953.0
# 2958    1953.0
# 1564    1953.0
# 3258    1953.0
# 3470    1953.0
# 1242    1953.0
# 1176    1953.0
# 3624    1953.0
# 3102    1953.0
# 2494    1953.0
# 559     1953.0
# 1914    1953.0
# 2481    1953.0
# 1904    1953.0
# 2018    1953.0
# 718     1953.0
# 2485    1954.0
# 2113    1954.0
# 1540    1954.0
# 2282    1954.0
# 3369    1954.0
# 3371    1954.0
# 3392    1954.0
# 140     1954.0
# 1351    1954.0
# 3454    1954.0
# 2207    1954.0
# 533     1954.0
# 3539    1954.0
# 3557    1954.0
# 2177    1954.0
# 3591    1954.0
# 3596    1954.0
# 3602    1954.0
# 365     1954.0
# 370     1954.0
# 2049    1954.0
# 1948    1954.0
# 3099    1954.0
# 466     1954.0
# 2517    1954.0
# 2528    1954.0
# 2572    1954.0
# 2598    1954.0
# 2609    1954.0
# 268     1954.0
# 1814    1954.0
# 2676    1954.0
# 2712    1954.0
# ...

# %%
pd.set_option('display.max_rows', len(data_set3))

# %%
data_set3.dtypes
# Out:
# customer_id                                     int64
# first_name                                     object
# last_name                                      object
# gender                                         object
# past_3_years_bike_related_purchases             int64
# DOB                                    datetime64[ns]
# job_title                                      object
# job_industry_category                          object
# wealth_segment                                 object
# deceased_indicator                             object
# default                                        object
# owns_car                                       object
# tenure                                        float64
# year                                          float64
# dtype: object

# %%
data_set3.columns
# Out:
# Index(['customer_id', 'first_name', 'last_name', 'gender',
#        'past_3_years_bike_related_purchases', 'DOB', 'job_title',
#        'job_industry_category', 'wealth_segment', 'deceased_indicator',
#        'default', 'owns_car', 'tenure', 'year'],
#       dtype='object')

# %%
col3 = ['customer_id', 'past_3_years_bike_related_purchases', 
        'tenure']

# %%
for j in col3:
    Q1 = data_set3[j].quantile(0.25)
    Q3 = data_set3[j].quantile(0.75)
    IQR = Q3 - Q1
    #print(IQR)

    for i in range(1, len(data_set3)):
        if (data_set3.loc[1, j] < (Q1 - 1.5 * IQR) == True):
            print("Outlier at", i, "in ", j)
        if (data_set3.loc[1, j] > (Q3 + 1.5 * IQR) == True):
            print("Outlier at", i, "in ", j)

# %%
data_set4 = pd.read_excel(open('kpmg_dataset.xlsx', 'rb'),
              sheet_name='CustomerAddress', skiprows = 1)

# %%
data_set4.head()
# Out:
#    customer_id              address  postcode            state    country  \
# 0            1   060 Morning Avenue      2016  New South Wales  Australia
# 1            2  6 Meadow Vale Court      2153  New South Wales  Australia
# 2            4   0 Holy Cross Court      4211              QLD  Australia
# 3            5  17979 Del Mar Point      2448  New South Wales  Australia
# 4            6     9 Oakridge Court      3216              VIC  Australia
#
#    property_valuation
# 0                  10
# 1                  10
# 2                   9
# 3                   4
# 4                   9

# %%
data_set4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3999 entries, 0 to 3998
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   customer_id         3999 non-null   int64
#  1   address             3999 non-null   object
#  2   postcode            3999 non-null   int64
#  3   state               3999 non-null   object
#  4   country             3999 non-null   object
#  5   property_valuation  3999 non-null   int64
# dtypes: int64(3), object(3)
# memory usage: 187.6+ KB

# %%
data_set4.isnull().sum()
# Out:
# customer_id           0
# address               0
# postcode              0
# state                 0
# country               0
# property_valuation    0
# dtype: int64

# %%
data_set4.columns
# Out:
# Index(['customer_id', 'address', 'postcode', 'state', 'country',
#        'property_valuation'],
#       dtype='object')

# %%
col4 = ['customer_id', 'postcode', 
       'property_valuation']

# %%
for j in col4:
    Q1 = data_set4[j].quantile(0.25)
    Q3 = data_set4[j].quantile(0.75)
    IQR = Q3 - Q1
    #print(IQR)

    for i in range(1, len(data_set4)):
        if (data_set4.loc[1, j] < (Q1 - 1.5 * IQR) == True):
            print("Outlier at", i, "in ", j)
        if (data_set4.loc[1, j] > (Q3 + 1.5 * IQR) == True):
            print("Outlier at", i, "in ", j)
